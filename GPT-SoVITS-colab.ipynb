# %% [markdown]
# <a href="https://colab.research.google.com/github/burizinho/drogax/blob/main/GPT-SoVITS-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 👇 Just Click the Play Button (Run) and Wait for Public Gradio Link

# %%
# @title Do Everything For Me and Launch Gradio
# %cd /content
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd /content/GPT-SoVITS

# Install system dependencies
# !apt-get update && apt-get install -y ffmpeg cmake gcc g++

# Install Python dependencies
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install opencc-python-reimplemented ffmpeg-python pyyaml pypinyin transformers==4.44.2 pytorch-lightning gradio==4.44.1 onnxruntime faster-whisper modelscope funasr wordsegment g2p_en

import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('cmudict')
nltk.download('punkt')
nltk.download('punkt_tab')

# !pip install huggingface_hub==0.23.5

import os
os.makedirs("GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large", exist_ok=True)
os.makedirs("GPT_SoVITS/pretrained_models/chinese-hubert-base", exist_ok=True)
os.makedirs("GPT_SoVITS/pretrained_models/sv", exist_ok=True)

# Download Core models
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/config.json -O GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/config.json
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/pytorch_model.bin -O GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/pytorch_model.bin
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/tokenizer.json -O GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/tokenizer.json
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-hubert-base/config.json -O GPT_SoVITS/pretrained_models/chinese-hubert-base/config.json
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-hubert-base/pytorch_model.bin -O GPT_SoVITS/pretrained_models/chinese-hubert-base/pytorch_model.bin
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-hubert-base/preprocessor_config.json -O GPT_SoVITS/pretrained_models/chinese-hubert-base/preprocessor_config.json
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/sv/pretrained_eres2netv2w24s4ep4.ckpt -O GPT_SoVITS/pretrained_models/sv/pretrained_eres2netv2w24s4ep4.ckpt

# Download V2 weights into the specific V2 directory to avoid FileNotFoundError
os.makedirs("GPT_SoVITS/pretrained_models/gsv-v2final-pretrained", exist_ok=True)
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2Gv2final0.pth -O GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s2Gv2final0.pth
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2Dv2final0.pth -O GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s2Dv2final0.pth
# !wget -qnc https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s1v2final-hotstep-10.ckpt -O GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s1v2final-hotstep-10.ckpt

# Copy them to root pretrained_models just in case
# !cp GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s2Gv2final0.pth GPT_SoVITS/pretrained_models/s2Gv2.pth
# !cp GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s2Dv2final0.pth GPT_SoVITS/pretrained_models/s2Dv2.pth
# !cp GPT_SoVITS/pretrained_models/gsv-v2final-pretrained/s1v2final-hotstep-10.ckpt GPT_SoVITS/pretrained_models/s1v2.ckpt

# Clean up the webui.py file to prevent repeated share arguments
# !sed -i 's/share=True,//g' webui.py
# !sed -i 's/share=is_share,//g' webui.py
# !sed -i 's/is_share=False/is_share=True/g' webui.py
# !sed -i 's/share=False/share=True/g' webui.py
# !sed -i 's/launch(/launch(share=True,/g' webui.py

# !python webui.py --share True
# Out:
# /content
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.
# /content/GPT-SoVITS
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://cli.github.com/packages stable InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# @title Baixar Modelos Pré-treinados Essenciais
import os
# %cd /content/GPT-SoVITS

# Criar diretórios necessários
os.makedirs("GPT_SoVITS/pretrained_models", exist_ok=True)
os.makedirs("GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large", exist_ok=True)
os.makedirs("GPT_SoVITS/pretrained_models/chinese-hubert-base", exist_ok=True)

print("Baixando modelos... isso pode levar alguns minutos.")

# Baixar modelos básicos necessários para o processamento de texto e áudio
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/config.json -O GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/config.json
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/pytorch_model.bin -O GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/pytorch_model.bin
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/tokenizer.json -O GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large/tokenizer.json
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-hubert-base/config.json -O GPT_SoVITS/pretrained_models/chinese-hubert-base/config.json
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-hubert-base/pytorch_model.bin -O GPT_SoVITS/pretrained_models/chinese-hubert-base/pytorch_model.bin

# Baixar modelos V2
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2Gv2.pth -O GPT_SoVITS/pretrained_models/s2Gv2.pth
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2Dv2.pth -O GPT_SoVITS/pretrained_models/s2Dv2.pth
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s1v2.ckpt -O GPT_SoVITS/pretrained_models/s1v2.ckpt

print("Modelos baixados! Agora você pode rodar a célula do Gradio novamente.")
# Out:
# /content/GPT-SoVITS
# Baixando modelos... isso pode levar alguns minutos.
# --2026-03-18 16:17:04--  https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/config.json
# Resolving huggingface.co (huggingface.co)... 3.167.112.38, 3.167.112.25, 3.167.112.96, ...
# Connecting to huggingface.co (huggingface.co)|3.167.112.38|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /api/resolve-cache/models/lj1995/GPT-SoVITS/336b2ec4e8d4ac74740798dd40af44e74659ecaf/chinese-roberta-wwm-ext-large%2Fconfig.json?%2Flj1995%2FGPT-SoVITS%2Fresolve%2Fmain%2Fchinese-roberta-wwm-ext-large%2Fconfig.json=&etag=%223ae58d7f0734373bb28d3b6b9d6858b34f600b4a%22 [following]
# ...

# %%
# @title Corrigir Downloads dos Modelos V2
import os
# %cd /content/GPT-SoVITS

print("Baixando pesos da V2 (Versão Estável)...")

# Criar diretório se não existir
os.makedirs("GPT_SoVITS/pretrained_models", exist_ok=True)

# URLs oficiais corrigidas (removendo subpasta redundante)
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2Gv2final0.pth -O GPT_SoVITS/pretrained_models/s2Gv2.pth
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s2Dv2final0.pth -O GPT_SoVITS/pretrained_models/s2Dv2.pth
# !wget https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/gsv-v2final-pretrained/s1v2final-hotstep-10.ckpt -O GPT_SoVITS/pretrained_models/s1v2.ckpt

# Garantir que os logs de treinamento existam
os.makedirs("logs/caneca", exist_ok=True)

print("Downloads concluídos! Agora você pode rodar a célula 'Do Everything For Me and Launch Gradio' no topo.")
# Out:
# /content/GPT-SoVITS
# Baixando pesos da V2 (Versão Estável)...
# --2026-03-18 16:18:53--  https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/pretrained_models/gsv-v2final-pretrained/s2Gv2final0.pth
# Resolving huggingface.co (huggingface.co)... 3.165.160.12, 3.165.160.61, 3.165.160.11, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.12|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-03-18 16:18:53 ERROR 404: Not Found.
#
# --2026-03-18 16:18:53--  https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/pretrained_models/gsv-v2final-pretrained/s2Dv2final0.pth
# Resolving huggingface.co (huggingface.co)... 3.165.160.12, 3.165.160.59, 3.165.160.61, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.12|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2026-03-18 16:18:53 ERROR 404: Not Found.
#
# ...

# %% [markdown]
# Let's break down the installation commands:
#
# *   `%cd /content`: This command changes the current working directory to `/content`. In Colab, `/content` is typically where you clone repositories.
#
# *   `!git clone https://github.com/RVC-Boss/GPT-SoVITS`: This command clones the `GPT-SoVITS` repository from GitHub into the current directory (`/content`). This downloads all the project files.
#
# *   `%cd /content/GPT-SoVITS`: After cloning, this command changes the directory into the newly cloned `GPT-SoVITS` folder.
#
# *   `!conda install -c conda-forge gcc gxx ffmpeg cmake`: This command uses `conda` (a package and environment manager) to install several essential tools:
#     *   `gcc`, `gxx`: C and C++ compilers, often required for building Python packages with C/C++ extensions.
#     *   `ffmpeg`: A powerful multimedia framework used for handling audio and video files, which is likely crucial for a voice synthesis project.
#     *   `cmake`: A cross-platform build system generator.
#     The `-c conda-forge` flag specifies the `conda-forge` channel, which provides a wide range of community-maintained packages.
#
# *   `!conda install pytorch==2.1.1 torchvision==0.16.1 torchaudio==2.1.1 pytorch-cuda=11.8 -c pytorch -c nvidia`: This command installs specific versions of PyTorch and related libraries:
#     *   `pytorch==2.1.1`: The main PyTorch deep learning framework, version 2.1.1.
#     *   `torchvision==0.16.1`: A package that provides datasets, models, and image transformations for computer vision tasks with PyTorch.
#     *   `torchaudio==2.1.1`: A package for audio processing with PyTorch.
#     *   `pytorch-cuda=11.8`: Specifies that the PyTorch installation should be compatible with CUDA Toolkit version 11.8, enabling GPU acceleration.
#     The `-c pytorch -c nvidia` flags specify the PyTorch and NVIDIA `conda` channels, respectively, to get the correct versions.
#
# *   `!pip install pyyaml`: This command installs the `pyyaml` library using `pip` (Python's package installer). It's used for parsing and emitting YAML data, which is a common configuration file format.
#
# *   `!pip install numba==0.56.4`: This installs a specific version of `numba`. Numba is a JIT compiler that translates Python and NumPy code into fast machine code, often used to speed up numerical operations.
#
# *   `!pip install -r requirements.txt`: This is a common practice in Python projects. It tells `pip` to install all the dependencies listed in the `requirements.txt` file located in the current directory (`/content/GPT-SoVITS`). This file typically contains a list of all other Python packages required by the project, often with specific version numbers.
#
# *   `!python webui.py`: This command executes the `webui.py` Python script. Based on the name, this script is likely responsible for launching the web user interface of the GPT-SoVITS project, which you would then interact with to use the voice synthesis features.
